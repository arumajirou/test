# %% [markdown]
# # PostgreSQL テーブル確認ノートブック
# このノートは `db_config.py` を読み込み、PostgreSQL からテーブル内容を確認します。
# - 接続情報: `db_config.py`（作業ディレクトリ直下 / `nf_featgen_bundle_v1/` / `db/` いずれか）
# - 代表テーブル: `public.features_hist`, `public.features_futr`
#
# 任意で `TABLE_SCHEMA`, `TABLE_HIST`, `TABLE_FUTR` を変更して使ってください。

# %%
# 0) セットアップ
import os, sys, importlib
from pathlib import Path
import pandas as pd
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus
import matplotlib.pyplot as plt
print(pd.__version__)
# Out:
# 2.3.3

# %%
# 1) db_config.py のロード
def _load_db_config():
    for p in [Path.cwd()/"db_config.py", Path.cwd()/"nf_featgen_bundle_v1"/"db_config.py", Path.cwd()/"db"/"db_config.py"]:
        if p.exists():
            spec = importlib.util.spec_from_file_location("db_config", str(p))
            mod = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(mod)
            print("Loaded:", p)
            return mod
    raise FileNotFoundError("db_config.py が見つかりません。")

db_cfg = _load_db_config()
DB_CONFIG = db_cfg.DB_CONFIG
TABLE_PREFIX = getattr(db_cfg, "TABLE_PREFIX", "")
DB_CONFIG
# Out:
# Loaded: /mnt/e/env/ts/test/db_config.py
# {'user': 'postgres',
#  'password': 'z',
#  'host': 'localhost',
#  'port': 5432,
#  'dbname': 'postgres'}

# %%
# 2) エンジン作成
def make_url(cfg: dict) -> str:
    if "url" in cfg and cfg["url"]:
        return cfg["url"]
    user = cfg.get("user") or cfg.get("username")
    pwd  = cfg.get("password") or cfg.get("pwd") or cfg.get("pass")
    host = cfg.get("host", "localhost")
    port = int(cfg.get("port", 5432))
    db   = cfg.get("dbname") or cfg.get("database") or cfg.get("db")
    if not (user and pwd and db):
        raise ValueError(f"DB設定を確認してください。渡されたキー: {list(cfg.keys())}")
    return f"postgresql+psycopg2://{quote_plus(user)}:{quote_plus(pwd)}@{host}:{port}/{db}"

engine = create_engine(make_url(DB_CONFIG), pool_pre_ping=True, future=True)
with engine.begin() as conn:
    print(conn.execute(text("SELECT current_user, current_database();")).all())
# Out:
# [('postgres', 'postgres')]

# %%
# 3) ユーティリティ
import pandas as pd
from sqlalchemy import text

def q(sql, params=None, limit=None):
    if limit is not None and "limit" not in sql.lower():
        sql = sql.rstrip(";") + f" LIMIT {int(limit)}"
    return pd.read_sql(text(sql), engine, params=params)

def list_tables_like(pattern="features%"):
    sql = '''
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_type='BASE TABLE' AND table_schema NOT IN ('pg_catalog','information_schema')
      AND table_name ILIKE :pat
    ORDER BY table_schema, table_name
    '''
    return q(sql, {"pat": pattern})

def table_preview(table, limit=5):
    return q(f"SELECT * FROM {table} ORDER BY 1", limit=limit)

def table_cols(table):
    sql = '''
    SELECT c.ordinal_position AS pos, c.column_name, c.data_type, c.is_nullable
    FROM information_schema.columns c
    WHERE (c.table_schema || '.' || c.table_name) = :tbl
    ORDER BY c.ordinal_position
    '''
    return q(sql, {"tbl": table})

def count_rows(table):
    return q(f"SELECT COUNT(*) AS n FROM {table}")
    
TABLE_SCHEMA = "public"
TABLE_HIST   = f"{TABLE_SCHEMA}.features_hist"
TABLE_FUTR   = f"{TABLE_SCHEMA}.features_futr"

list_tables_like("features%")
# Out:
#   table_schema     table_name
# 0       public  features_futr
# 1       public  features_hist

# %%
# 4) 先頭5行のプレビュー
table_preview(TABLE_HIST, limit=5)
# Out:
#   unique_id         ds  hist_y_lag1 hist_y_lag7 hist_y_lag14 hist_y_lag28  \
# 0        N1 1999-04-27          1.0        None         None         None
# 1        N1 1999-05-11          2.0        None         None         None
# 2        N1 1999-05-25          1.0        None         None         None
# 3        N1 1999-06-08         11.0        None         None         None
# 4        N1 1999-04-13          NaN        None         None         None
#
#    hist_y_roll_mean_7  hist_y_roll_std_7 hist_y_roll_mean_28  hist_y_diff_1  \
# 0                 NaN                NaN                None            1.0
# 1            1.500000           0.707107                None           -1.0
# 2            1.333333           0.577350                None           10.0
# 3            3.750000           4.856267                None           -3.0
# 4                 NaN                NaN                None            NaN
#
#    ... futr_fourier_P365_s1  futr_fourier_P365_c1  futr_fourier_P365_s2  \
# 0  ...            -0.796183             -0.605056              0.963471
# 1  ...            -0.917584             -0.397543              0.729558
# 2  ...            -0.985948             -0.167052              0.329408
# 3  ...            -0.997325              0.073095             -0.145799
# 4  ...            -0.628763             -0.777597              0.977848
#
#    futr_fourier_P365_c2  futr_fourier_P365_s3  futr_fourier_P365_c3  \
# 0             -0.267814             -0.369725              0.929141
# 1             -0.683919              0.337523              0.941317
# 2             -0.944188              0.875892              0.482508
# 3             -0.989314              0.976011             -0.217723
# 4              0.209315             -0.891981              0.452072
#
#    futr_fourier_P365_s4  futr_fourier_P365_c4  futr_fourier_P365_s5  \
# 0             -0.516062             -0.856551              0.994218
# 1             -0.997917             -0.064508              0.455907
# 2             -0.622047              0.782980             -0.668064
# 3              0.288482              0.957485             -0.933837
# 4              0.409356             -0.912375              0.255353
#
#    futr_fourier_P365_c5
# 0              0.107381
# 1             -0.890028
# 2             -0.744104
# 3              0.357698
# 4              0.966848
#
# [5 rows x 40 columns]

# %%
table_preview(TABLE_FUTR, limit=5)
# Out:
#   unique_id         ds  futr_year  futr_quarter  futr_month  futr_weekofyear  \
# 0        N1 2025-11-14       2025             4          11               46
# 1        N1 2025-11-15       2025             4          11               46
# 2        N1 2025-11-16       2025             4          11               46
# 3        N1 2025-11-17       2025             4          11               47
# 4        N1 2025-11-13       2025             4          11               46
#
#    futr_day  futr_dayofweek  futr_is_month_start  futr_is_month_end  ...  \
# 0        14               4                    0                  0  ...
# 1        15               5                    0                  0  ...
# 2        16               6                    0                  0  ...
# 3        17               0                    0                  0  ...
# 4        13               3                    0                  0  ...
#
#    futr_fourier_P365_s1  futr_fourier_P365_c1  futr_fourier_P365_s2  \
# 0              0.977848              0.209315              0.409356
# 1              0.981306              0.192452              0.377708
# 2              0.984474              0.175531              0.345612
# 3              0.987349              0.158559              0.313107
# 4              0.974100              0.226116              0.440519
#
#    futr_fourier_P365_c2  futr_fourier_P365_s3  futr_fourier_P365_c3  \
# 0             -0.912375             -0.806480             -0.591261
# 1             -0.925925             -0.835925             -0.548843
# 2             -0.938377             -0.863142             -0.504961
# 3             -0.949718             -0.888057             -0.459733
# 4             -0.897743             -0.774884             -0.632103
#
#    futr_fourier_P365_s4  futr_fourier_P365_c4  futr_fourier_P365_s5  \
# 0             -0.746972              0.664855              0.493776
# 1             -0.699458              0.714673              0.566702
# 2             -0.648630              0.761104              0.635432
# 3             -0.594727              0.803928              0.699458
# 4             -0.790946              0.611886              0.417194
#
#    futr_fourier_P365_c5
# 0              0.869589
# 1              0.823923
# 2              0.772157
# 3              0.714673
# 4              0.908818
#
# [5 rows x 29 columns]

# %%
# 5) 行数・列情報
count_rows(TABLE_HIST), count_rows(TABLE_FUTR)
# Out:
# (       n
#  0  27217,
#       n
#  0  224)

# %%
table_cols(TABLE_HIST)
# Out:
#     pos                  column_name                    data_type is_nullable
# 0     1                    unique_id                         text         YES
# 1     2                           ds  timestamp without time zone         YES
# 2     3                  hist_y_lag1             double precision         YES
# 3     4                  hist_y_lag7             double precision         YES
# 4     5                 hist_y_lag14             double precision         YES
# 5     6                 hist_y_lag28             double precision         YES
# 6     7           hist_y_roll_mean_7             double precision         YES
# 7     8            hist_y_roll_std_7             double precision         YES
# 8     9          hist_y_roll_mean_28             double precision         YES
# 9    10                hist_y_diff_1             double precision         YES
# 10   11     hist_y_anom_hampel_z_w28                         real         YES
# 11   12  hist_y_anom_hampel_flag_w28                     smallint         YES
# 12   13               hist_valid_w28                     smallint         YES
# 13   14                    futr_year                      integer         YES
# 14   15                 futr_quarter                      integer         YES
# 15   16                   futr_month                      integer         YES
# 16   17              futr_weekofyear                       bigint         YES
# 17   18                     futr_day                      integer         YES
# 18   19               futr_dayofweek                      integer         YES
# 19   20          futr_is_month_start                     smallint         YES
# 20   21            futr_is_month_end                     smallint         YES
# 21   22        futr_is_quarter_start                     smallint         YES
# 22   23          futr_is_quarter_end                     smallint         YES
# 23   24              futr_is_weekend                     smallint         YES
# 24   25           futr_fourier_P7_s1             double precision         YES
# 25   26           futr_fourier_P7_c1             double precision         YES
# 26   27           futr_fourier_P7_s2             double precision         YES
# 27   28           futr_fourier_P7_c2             double precision         YES
# 28   29           futr_fourier_P7_s3             double precision         YES
# 29   30           futr_fourier_P7_c3             double precision         YES
# 30   31         futr_fourier_P365_s1             double precision         YES
# 31   32         futr_fourier_P365_c1             double precision         YES
# 32   33         futr_fourier_P365_s2             double precision         YES
# 33   34         futr_fourier_P365_c2             double precision         YES
# 34   35         futr_fourier_P365_s3             double precision         YES
# 35   36         futr_fourier_P365_c3             double precision         YES
# 36   37         futr_fourier_P365_s4             double precision         YES
# 37   38         futr_fourier_P365_c4             double precision         YES
# 38   39         futr_fourier_P365_s5             double precision         YES
# 39   40         futr_fourier_P365_c5             double precision         YES

# %%
table_cols(TABLE_FUTR)
# Out:
#     pos            column_name                    data_type is_nullable
# 0     1              unique_id                         text         YES
# 1     2                     ds  timestamp without time zone         YES
# 2     3              futr_year                      integer         YES
# 3     4           futr_quarter                      integer         YES
# 4     5             futr_month                      integer         YES
# 5     6        futr_weekofyear                       bigint         YES
# 6     7               futr_day                      integer         YES
# 7     8         futr_dayofweek                      integer         YES
# 8     9    futr_is_month_start                     smallint         YES
# 9    10      futr_is_month_end                     smallint         YES
# 10   11  futr_is_quarter_start                     smallint         YES
# 11   12    futr_is_quarter_end                     smallint         YES
# 12   13        futr_is_weekend                     smallint         YES
# 13   14     futr_fourier_P7_s1             double precision         YES
# 14   15     futr_fourier_P7_c1             double precision         YES
# 15   16     futr_fourier_P7_s2             double precision         YES
# 16   17     futr_fourier_P7_c2             double precision         YES
# 17   18     futr_fourier_P7_s3             double precision         YES
# 18   19     futr_fourier_P7_c3             double precision         YES
# 19   20   futr_fourier_P365_s1             double precision         YES
# 20   21   futr_fourier_P365_c1             double precision         YES
# 21   22   futr_fourier_P365_s2             double precision         YES
# 22   23   futr_fourier_P365_c2             double precision         YES
# 23   24   futr_fourier_P365_s3             double precision         YES
# 24   25   futr_fourier_P365_c3             double precision         YES
# 25   26   futr_fourier_P365_s4             double precision         YES
# 26   27   futr_fourier_P365_c4             double precision         YES
# 27   28   futr_fourier_P365_s5             double precision         YES
# 28   29   futr_fourier_P365_c5             double precision         YES

# %%
# 6) 時系列プロット（matplotlibのみ / 単独プロット / 色指定なし）
uid = q(f"SELECT DISTINCT unique_id FROM {TABLE_HIST} ORDER BY 1 LIMIT 1").iloc[0,0]
df = q(f"""SELECT unique_id, ds, y
FROM {TABLE_HIST}
WHERE unique_id = :uid
ORDER BY ds
""" , {"uid": uid})
print("unique_id:", uid, "rows:", len(df))

import matplotlib.pyplot as plt
plt.figure()
plt.plot(df["ds"], df["y"])  # 色は指定しない
plt.title(f"y over time - {uid}")
plt.xlabel("ds")
plt.ylabel("y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# UndefinedColumn: column "y" does not exist
# LINE 1: SELECT unique_id, ds, y
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 3
#       1 # 6) 時系列プロット（matplotlibのみ / 単独プロット / 色指定なし）
#       2 uid = q(f"SELECT DISTINCT unique_id FROM {TABLE_HIST} ORDER BY 1 LIMIT 1").iloc[0,0]
# ----> 3 df = q(f"""SELECT unique_id, ds, y
#       4 FROM {TABLE_HIST}
#       5 WHERE unique_id = :uid
#       6 ORDER BY ds
#       7 """ , {"uid": uid})
#       8 print("unique_id:", uid, "rows:", len(df))
#      10 import matplotlib.pyplot as plt
#
# Cell In[5], line 8, in q(sql, params, limit)
#       6 if limit is not None and "limit" not in sql.lower():
#       7     sql = sql.rstrip(";") + f" LIMIT {int(limit)}"
# ----> 8 return pd.read_sql(text(sql), engine, params=params)
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/pandas/io/sql.py:736, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     726     return pandas_sql.read_table(
#     727         sql,
#     728         index_col=index_col,
#    (...)    733         dtype_backend=dtype_backend,
#     734     )
#     735 else:
# --> 736     return pandas_sql.read_query(
#     737         sql,
#     738         index_col=index_col,
#     739         params=params,
#     740         coerce_float=coerce_float,
#     741         parse_dates=parse_dates,
#     742         chunksize=chunksize,
#     743         dtype_backend=dtype_backend,
#     744         dtype=dtype,
#     745     )
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/pandas/io/sql.py:1848, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1791 def read_query(
#    1792     self,
#    1793     sql: str,
#    (...)   1800     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1801 ) -> DataFrame | Iterator[DataFrame]:
#    1802     """
#    1803     Read SQL query into a DataFrame.
#    1804
#    (...)   1846
#    1847     """
# -> 1848     result = self.execute(sql, params)
#    1849     columns = result.keys()
#    1851     if chunksize is not None:
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/pandas/io/sql.py:1672, in SQLDatabase.execute(self, sql, params)
#    1670 if isinstance(sql, str):
#    1671     return self.con.exec_driver_sql(sql, *args)
# -> 1672 return self.con.execute(sql, *args)
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/envs/nc/lib/python3.11/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "y" does not exist
# LINE 1: SELECT unique_id, ds, y
#                               ^
#
# [SQL: SELECT unique_id, ds, y
# FROM public.features_hist
# WHERE unique_id = %(uid)s
# ORDER BY ds
# ]
# [parameters: {'uid': 'N1'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
