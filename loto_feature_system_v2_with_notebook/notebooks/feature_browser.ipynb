# %% [markdown]
# # 特徴量テーブル閲覧ノートブック（JupyterLab）
#
# このノートブックは `loto_feature_system_v2` プロジェクトの出力（`artifacts/` 配下の特徴量CSV）を読み込み、
# テーブルの中身を確認するための最小セットです。
#
# - 生成対象: `features_hist.csv`, `features_futr.csv`, `features_stat.csv`
# - もしファイルが存在しない場合は、**オプション**で同梱のサンプルデータからパイプラインを実行して生成できます。

# %%
# パス設定（このノートブックはプロジェクト直下で動かす想定）
from pathlib import Path
import pandas as pd

BASE = Path('.').resolve()
ART = BASE / 'artifacts'
CFG = BASE / 'config' / 'pipeline_config.yaml'
SAMPLE = BASE / 'examples' / 'sample_loto.csv'

HIST = ART / 'features_hist.csv'
FUTR = ART / 'features_futr.csv'
STAT = ART / 'features_stat.csv'

display({
    "BASE": str(BASE),
    "ARTIFACTS_DIR": str(ART),
    "HIST": str(HIST),
    "FUTR": str(FUTR),
    "STAT": str(STAT),
})
# Out:
# {'BASE': '/mnt/e/env/ts/test/loto_feature_system_v2_with_notebook/notebooks',
#  'ARTIFACTS_DIR': '/mnt/e/env/ts/test/loto_feature_system_v2_with_notebook/notebooks/artifacts',
#  'HIST': '/mnt/e/env/ts/test/loto_feature_system_v2_with_notebook/notebooks/artifacts/features_hist.csv',
#  'FUTR': '/mnt/e/env/ts/test/loto_feature_system_v2_with_notebook/notebooks/artifacts/features_futr.csv',
#  'STAT': '/mnt/e/env/ts/test/loto_feature_system_v2_with_notebook/notebooks/artifacts/features_stat.csv'}

# %%
# %cd /mnt/e/env/ts/test
# Out:
# /mnt/e/env/ts/test

# %%
# !tree
# Out:
# .
# ├── Core-Nixtla.md
# ├── Explore_Original_LongTable.ipynb
# ├── Explore_Postgres_FeatureTables.ipynb
# ├── INSTALL.md
# ├── N4.csv
# ├── README.md
# ├── __pycache__
# │   ├── db_config.cpython-311.pyc
# │   ├── postgres_manager.cpython-311.pyc
# │   └── postgres_manager.cpython-313.pyc
# ├── artifacts
# ├── bundles
# │   ├── 01_NeuralForecast.md
# │   ├── 02_Ray.md
# │   ├── 03_Optuna.md
# │   ├── 03_optunareadthedocsio.md
# │   ├── 04_MLflow.md
# │   ├── 05_MLflow-Databricks.md
# │   ├── 06_GitHub.md
# │   ├── 07_Lightning.md
# │   ├── https___nixtlaverse.md
# │   └── パラメータ.md
# ├── cache
# ├── config
# │   ├── db_config.yaml.template
# │   ├── default_config.yaml
# │   ├── logging_config.yaml
# │   └── pipeline_config.yaml
# ├── configs
# │   ├── CONFIG_DESIGN.md
# │   ├── OVERVIEW.md
# │   ├── README.md
# │   ├── config_loader.py
# │   ├── configs_README.md
# │   ├── default_configs.yaml
# │   ├── example_config_usage.py
# │   └── model_characteristics.yaml
# ├── configszip
# │   ├── OVERVIEW.md
# │   ├── configs_README.md
# │   ├── default_configs.yaml
# │   └── model_characteristics.yaml
# ├── db
# │   ├── __init__.py
# │   ├── __pycache__
# │   │   ├── db_config.cpython-311.pyc
# │   │   └── loto_etl.cpython-311.pyc
# │   ├── db_config.py
# │   ├── loto_etl.py
# │   ├── loto_pg_store.py
# │   ├── postgres_manager.py
# │   └── setup_postgres.py
# ├── db_config.py
# ├── docs
# │   ├── API_REFERENCE.md
# │   ├── Claude-Documentation structure setup.md
# │   ├── Claude-Lead engineer framework for AutoModels backend optimization.md
# │   ├── Claude-Python factory pattern module structure.md
# │   ├── Claude-Time series feature engineering system design.md
# │   ├── DESIGN_OVERVIEW.md
# │   ├── IMPLEMENTATION_PLAN.md
# │   ├── LOTO_FEATURE_SYSTEM_DESIGN.md
# │   ├── QUICKSTART.md
# │   ├── README.md
# │   ├── TROUBLESHOOTING.md
# │   ├── TUTORIAL.md
# │   └── hist.md
# ├── examples
# │   └── sample_loto.csv
# ├── logs
# ├── loto_feature_system_v2
# │   ├── README.md
# │   ├── artifacts
# │   │   ├── features_futr.csv
# │   │   ├── features_hist.csv
# │   │   └── features_stat.csv
# │   ├── cache
# │   ├── config
# │   │   ├── db_config.yaml.template
# │   │   ├── default_config.yaml
# │   │   ├── logging_config.yaml
# │   │   └── pipeline_config.yaml
# │   ├── examples
# │   │   └── sample_loto.csv
# │   ├── logs
# │   ├── pytest.ini
# │   ├── requirements-gpu.txt
# │   ├── requirements.txt
# │   ├── scripts
# │   │   ├── install.sh
# │   │   └── run_pipeline.py
# │   ├── setup.py
# │   ├── src
# │   │   ├── __init__.py
# │   │   ├── __pycache__
# │   │   │   └── __init__.cpython-311.pyc
# │   │   ├── core
# │   │   │   ├── __init__.py
# │   │   │   ├── __pycache__
# │   │   │   │   ├── __init__.cpython-311.pyc
# │   │   │   │   ├── data_loader.cpython-311.pyc
# │   │   │   │   └── feature_orchestrator.cpython-311.pyc
# │   │   │   ├── data_loader.py
# │   │   │   ├── database_manager.py
# │   │   │   └── feature_orchestrator.py
# │   │   ├── integration
# │   │   │   ├── __init__.py
# │   │   │   ├── dask_integration.py
# │   │   │   └── ray_integration.py
# │   │   ├── pipelines
# │   │   │   ├── __init__.py
# │   │   │   ├── __pycache__
# │   │   │   │   ├── __init__.cpython-311.pyc
# │   │   │   │   ├── base_pipeline.cpython-311.pyc
# │   │   │   │   └── loto_pipeline.cpython-311.pyc
# │   │   │   ├── base_pipeline.py
# │   │   │   └── loto_pipeline.py
# │   │   └── utils
# │   │       ├── __init__.py
# │   │       ├── __pycache__
# │   │       │   ├── __init__.cpython-311.pyc
# │   │       │   ├── logging_config.cpython-311.pyc
# │   │       │   └── validation.cpython-311.pyc
# │   │       ├── gpu_utils.py
# │   │       ├── logging_config.py
# │   │       ├── metrics.py
# │   │       └── validation.py
# │   └── tests
# │       ├── __init__.py
# │       └── test_core
# │           ├── __init__.py
# │           └── test_data_loader.py
# ├── loto_feature_system_v2.zip
# ├── loto_feature_system_v2_with_notebook
# │   ├── README.md
# │   ├── artifacts
# │   ├── cache
# │   ├── config
# │   │   ├── db_config.yaml.template
# │   │   ├── default_config.yaml
# │   │   ├── logging_config.yaml
# │   │   └── pipeline_config.yaml
# │   ├── examples
# │   │   └── sample_loto.csv
# │   ├── logs
# │   ├── notebooks
# │   │   └── feature_browser.ipynb
# │   ├── pytest.ini
# │   ├── requirements-gpu.txt
# │   ├── requirements.txt
# │   ├── scripts
# │   │   ├── install.sh
# │   │   └── run_pipeline.py
# │   ├── setup.py
# │   ├── src
# │   │   ├── __init__.py
# │   │   ├── core
# │   │   │   ├── __init__.py
# │   │   │   ├── data_loader.py
# │   │   │   ├── database_manager.py
# │   │   │   └── feature_orchestrator.py
# │   │   ├── integration
# │   │   │   ├── __init__.py
# │   │   │   ├── dask_integration.py
# │   │   │   └── ray_integration.py
# │   │   ├── pipelines
# │   │   │   ├── __init__.py
# │   │   │   ├── base_pipeline.py
# │   │   │   └── loto_pipeline.py
# │   │   └── utils
# │   │       ├── __init__.py
# │   │       ├── gpu_utils.py
# │   │       ├── logging_config.py
# │   │       ├── metrics.py
# │   │       └── validation.py
# │   └── tests
# │       ├── __init__.py
# │       └── test_core
# │           ├── __init__.py
# │           └── test_data_loader.py
# ├── loto_feature_system_v2_with_notebook.zip
# ├── neuralforecast_bundle.md
# ├── nf_auto_runs
# │   └── run_20251112-075246
# │       ├── meta.json
# │       ├── models
# │       │   ├── AutoPatchTST_0.ckpt
# │       │   ├── AutoTFT_0.ckpt
# │       │   ├── alias_to_model.pkl
# │       │   ├── configuration.pkl
# │       │   └── dataset.pkl
# │       ├── plots
# │       │   └── last_window.png
# │       └── tables
# │           ├── cv_predictions.csv
# │           └── metrics.csv
# ├── nf_docs_bundle
# │   ├── CHANGELOG.md
# │   ├── README.md
# │   ├── docs
# │   │   ├── DATA_FORMAT.md
# │   │   ├── QUICKSTART.md
# │   │   └── RAY_ON_WINDOWS.md
# │   └── requirements.txt
# ├── nf_featgen_bundle_v1
# │   ├── README.md
# │   ├── __pycache__
# │   │   └── db_config.cpython-311.pyc
# │   ├── cli_make_features_from_db.py
# │   ├── config_default.yaml
# │   ├── db_config.py
# │   ├── db_config.py.template
# │   ├── featgen
# │   │   ├── __init__.py
# │   │   ├── __pycache__
# │   │   │   ├── __init__.cpython-311.pyc
# │   │   │   ├── db_utils.cpython-311.pyc
# │   │   │   ├── feature_naming.cpython-311.pyc
# │   │   │   ├── providers_basic.cpython-311.pyc
# │   │   │   └── runner_db.cpython-311.pyc
# │   │   ├── config_default.yaml
# │   │   ├── db_utils.py
# │   │   ├── feature_naming.py
# │   │   ├── providers_basic.py
# │   │   └── runner_db.py
# │   └── requirements.txt
# ├── pytest.ini
# ├── requirements-gpu.txt
# ├── requirements.txt
# ├── scripts
# │   ├── install.sh
# │   └── run_pipeline.py
# ├── setup.py
# ├── silent-test.ipynb
# ├── smoke_optuna.py
# ├── smoke_ray.py
# ├── src
# │   ├── __init__.py
# │   ├── apply_patches_auto_model_factory.py
# │   ├── auto_model_factory.py
# │   ├── auto_model_factory_fixed.py
# │   ├── core
# │   │   ├── __init__.py
# │   │   ├── data_loader.py
# │   │   ├── database_manager.py
# │   │   └── feature_orchestrator.py
# │   ├── example_usage.py
# │   ├── integration
# │   │   ├── __init__.py
# │   │   ├── dask_integration.py
# │   │   └── ray_integration.py
# │   ├── logging_config.py
# │   ├── mlflow_integration.py
# │   ├── mlflow_integration.py.bak
# │   ├── model_characteristics.py
# │   ├── pipelines
# │   │   ├── __init__.py
# │   │   ├── base_pipeline.py
# │   │   └── loto_pipeline.py
# │   ├── search_algorithm_selector.py
# │   ├── utils
# │   │   ├── __init__.py
# │   │   ├── gpu_utils.py
# │   │   ├── logging_config.py
# │   │   ├── metrics.py
# │   │   └── validation.py
# │   └── validation.py
# ├── test.ipynb
# └── tests
#     ├── __init__.py
#     ├── integration
#     │   ├── conftest.py
#     │   └── test_end_to_end_workflow.py
#     ├── performance
#     │   └── test_optimization_performance.py
#     ├── test_core
#     │   ├── __init__.py
#     │   └── test_data_loader.py
#     └── unit
#         ├── test_auto_model_factory.py
#         ├── test_logging_config.py
#         ├── test_mlflow_integration.py
#         ├── test_model_characteristics.py
#         ├── test_search_algorithm_selector.py
#         └── test_validation.py
#
# 68 directories, 218 files

# %%
# 必要に応じてパイプラインを実行（サンプル）
# run_if_missing=True の場合、features_*.csv が無ければ生成します。
run_if_missing = True

def _maybe_run_pipeline():
    import importlib, sys
    from pathlib import Path
    sys.path.insert(0, str(BASE))  # src を相対import
    try:
        from src.pipelines.loto_pipeline import run as run_pipeline
    except Exception as e:
        print("パイプラインのimportに失敗:", e)
        return
    ART.mkdir(parents=True, exist_ok=True)
    print("パイプライン実行中...")
    res = run_pipeline(str(SAMPLE), str(ART), str(CFG))
    print("生成完了:", res)

if run_if_missing and not (HIST.exists() and FUTR.exists() and STAT.exists()):
    _maybe_run_pipeline()
else:
    print("features_*.csv が見つかりました（または実行スキップ）。")
# Out:
# パイプラインのimportに失敗: No module named 'src.pipelines.loto_pipeline'

# %%
# 読み込み（存在チェック付き）
def _safe_read_csv(p: Path):
    if not p.exists():
        print(f"ないよ: {p}")
        return None
    try:
        df = pd.read_csv(p)
    except Exception as e:
        print(f"読込失敗: {p} -> {e}")
        return None
    return df

df_hist = _safe_read_csv(HIST)
df_futr = _safe_read_csv(FUTR)
df_stat = _safe_read_csv(STAT)

for name, df in [("hist", df_hist), ("futr", df_futr), ("stat", df_stat)]:
    if df is not None:
        print(f"{name}: shape={df.shape}")
        display(df.head(10))

# %%
# ユーティリティ: フィルタ & プレビュー
import pandas as pd

def preview_hist(unique_id=None, start=None, end=None, cols=None, head=20):
    if df_hist is None:
        print("df_hist がありません")
        return None
    out = df_hist.copy()
    if unique_id is not None:
        out = out[out['unique_id'] == unique_id]
    if start is not None:
        out = out[out['ds'] >= str(start)]
    if end is not None:
        out = out[out['ds'] <= str(end)]
    if cols is not None:
        keep = ['unique_id','ds'] + [c for c in cols if c in out.columns]
        out = out[keep]
    display(out.head(head))
    return out

# 例: 指定系列の先頭20行
_ = preview_hist(unique_id='loto6', head=20)

# %%
# 結合ビュー（左結合でざっくり確認）
def merged_view(limit=50):
    if (df_hist is None) or (df_futr is None) or (df_stat is None):
        print("いずれかのテーブルがありません")
        return None
    m = df_hist.merge(df_futr, on=['unique_id','ds'], how='left')\
               .merge(df_stat, on=['unique_id'], how='left')
    display(m.head(limit))
    return m

_ = merged_view(30)

# %%
# 簡単な統計・欠損プロファイル
def profile(df, name):
    if df is None:
        return
    print(f"[{name}] shape={df.shape}")
    display(pd.DataFrame({
        "dtype": df.dtypes.astype(str),
        "n_unique": df.nunique(),
        "n_missing": df.isna().sum(),
    }))

profile(df_hist, "hist")
profile(df_futr, "futr")
profile(df_stat, "stat")

# %%
# （任意）可視化例: 任意列の折れ線
# 実行時に 'unique_id' と列名 'col' を指定してください。
import matplotlib.pyplot as plt

def plot_series(unique_id='loto6', col='y', head=None):
    if df_hist is None:
        print("df_hist がありません")
        return
    d = df_hist[df_hist['unique_id'] == unique_id].copy()
    if head is not None:
        d = d.head(head)
    # ds を日付に
    try:
        d['ds'] = pd.to_datetime(d['ds'])
    except Exception:
        pass
    d = d.sort_values('ds')
    if col not in d.columns:
        print(f"列がありません: {col}")
        return
    plt.figure()
    plt.plot(d['ds'], d[col])
    plt.title(f"{unique_id} - {col}")
    plt.xlabel("ds")
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# plot_series('loto6', 'y')  # 必要ならコメントアウトを外して実行
